# %% [markdown]
# ## 1. Создание базы и таблиц

# %% [markdown]
# Подключимся к базе

# %%
import psycopg2

con = psycopg2.connect(
  database="russian-news", 
  user="postgres", 
  password="passcode4854", 
  host="127.0.0.1", 
  port="5432"
)

print("Database opened successfully")
# Out:
# Database opened successfully

# %% [markdown]
# Создадим таблицу, зададим ее структуру. Нам нужны 5 столбцов: id, издание, дата публикации, название, текст

# %%
con = psycopg2.connect(
  database="russian-news", 
  user="postgres", 
  password="passcode4854", 
  host="127.0.0.1", 
  port="5432"
)
cur = con.cursor()  
cur.execute('''CREATE TABLE corpus  
     (id SERIAL,
     newspaper TEXT NOT NULL,
     date TEXT NOT NULL,
     title TEXT NOT NULL,
     article TEXT NOT NULL);''')

print("Table created successfully")
con.commit()  
con.close()
# Out:
# Table created successfully

# %% [markdown]
# Возьмем по 100 статей Ленты, РИА-новостей и Известий за 2001, 2002 и 2003 год. Поместим их в список кортежей и последовательно запишем в таблицу.

# %%
import os
import unicodedata

# %%
# %%time
corp = []
for i in range(2001, 2004):
    for fl in os.listdir('data/lenta/lenta{}/'.format(i))[:100]:
        with open('data/lenta/lenta{}/'.format(i) + fl, 'r', encoding='UTF-8') as f:
            file = f.readlines()
            tuple_line = ('lenta', unicodedata.normalize("NFKD",file[0]).strip('\n'), unicodedata.normalize("NFKD",file[1]).strip('\n'), ' '.join(unicodedata.normalize("NFKD",file) for file in file[2:]))
            corp.append(tuple_line)
# Out:
# Wall time: 209 ms

# %%
# %%time
for i in range(2001, 2004):
    for fl in os.listdir('data/izvestiya/izvestiya{}/'.format(i))[:100]:
        with open('data/izvestiya/izvestiya{}/'.format(i) + fl, 'r', encoding='UTF-8') as f:
            file = f.readlines()
            tuple_line = ('izvestiya', unicodedata.normalize("NFKD",file[0]).strip('\n'), unicodedata.normalize("NFKD",file[1]).strip('\n'), ' '.join(unicodedata.normalize("NFKD",file) for file in file[2:]))
            corp.append(tuple_line)
# Out:
# Wall time: 113 ms

# %%
# %%time
for i in range(2001, 2004):
    for fl in os.listdir('data/ria/ria{}/'.format(i))[:100]:
        with open('data/ria/ria{}/'.format(i) + fl, 'r', encoding='UTF-8') as f:
            file = f.readlines()
            tuple_line = ('ria', unicodedata.normalize("NFKD",file[0]).strip('\n'), unicodedata.normalize("NFKD",file[1]).strip('\n'), ' '.join(unicodedata.normalize("NFKD",file) for file in file[2:]))
            corp.append(tuple_line)
# Out:
# Wall time: 440 ms

# %%
# %%time
con = psycopg2.connect(
  database="russian-news", 
  user="postgres", 
  password="passcode4854", 
  host="127.0.0.1", 
  port="5432"
)
user_records = ", ".join(["%s"] * len(corp))

insert_query = (
    f"INSERT INTO corpus (newspaper, date, title, article) VALUES {user_records}"
)

cursor = con.cursor()
cursor.execute(insert_query, corp)
con.commit()  
con.close()
# Out:
# Wall time: 846 ms

# %% [markdown]
# Создадим еще одну таблицу, куда запишем количество слов в статьях. Нам понадобятся три столбца: id, название и количество слов:

# %%
# %%time
n_words = []
for i in corp:
    tuple_line = (i[2], len(i[3].split()))
    n_words.append(tuple_line)
# Out:
# Wall time: 34.5 ms

# %%
con = psycopg2.connect(
  database="russian-news", 
  user="postgres", 
  password="passcode4854", 
  host="127.0.0.1", 
  port="5432"
)
cur = con.cursor()  
cur.execute('''CREATE TABLE corpus_words  
     (id SERIAL,
     title TEXT NOT NULL,
     n_words INT NOT NULL);''')

print("Table created successfully")
con.commit()  
con.close()
# Out:
# Table created successfully

# %%
# %%time
con = psycopg2.connect(
  database="russian-news", 
  user="postgres", 
  password="passcode4854", 
  host="127.0.0.1", 
  port="5432"
)
user_records = ", ".join(["%s"] * len(n_words))

insert_query = (
    f"INSERT INTO corpus_words (title, n_words) VALUES {user_records}"
)

cursor = con.cursor()
cursor.execute(insert_query, n_words)
con.commit()  
con.close()
# Out:
# Wall time: 103 ms

# %% [markdown]
# Создадим третью таблицу, куда запишем количество предложений в статьях. Понадобятся 3 столбца: id, название и количество предложений:

# %%
n_sents = []
for i in corp:
    tuple_line = (i[2], len(i[3].split('.')))
    n_sents.append(tuple_line)

# %%
con = psycopg2.connect(
  database="russian-news", 
  user="postgres", 
  password="passcode4854", 
  host="127.0.0.1", 
  port="5432"
)
cur = con.cursor()  
cur.execute('''CREATE TABLE corpus_sents  
     (id SERIAL,
     title TEXT NOT NULL,
     n_sents INT NOT NULL);''')

print("Table created successfully")
con.commit()  
con.close()
# Out:
# Table created successfully

# %%
# %%time
con = psycopg2.connect(
  database="russian-news", 
  user="postgres", 
  password="passcode4854", 
  host="127.0.0.1", 
  port="5432"
)
user_records = ", ".join(["%s"] * len(n_sents))

insert_query = (
    f"INSERT INTO corpus_sents (title, n_sents) VALUES {user_records}"
)

cursor = con.cursor()
cursor.execute(insert_query, n_sents)
con.commit()  
con.close()
# Out:
# Wall time: 89.8 ms

# %% [markdown]
# ## 2. Манипуляция данными

# %% [markdown]
# Заменим все статьи Ленты, которые были написаны в 2001 году, на 0:

# %%
# %%time
con = psycopg2.connect(
  database="russian-news", 
  user="postgres", 
  password="passcode4854", 
  host="127.0.0.1", 
  port="5432"
)
cur = con.cursor()
cur.execute("UPDATE corpus SET article = 0 WHERE date LIKE '2001%' AND newspaper = 'lenta'")
con.commit()  
con.close()
# Out:
# Wall time: 102 ms

# %% [markdown]
# Удалим все статьи Ленты за 2001 год:

# %%
# %%time
con = psycopg2.connect(
  database="russian-news", 
  user="postgres", 
  password="passcode4854", 
  host="127.0.0.1", 
  port="5432"
)
cur = con.cursor()
cur.execute("DELETE FROM corpus WHERE date LIKE '2001%' AND newspaper = 'lenta'")
con.commit()  
con.close()
# Out:
# Wall time: 85.8 ms

# %% [markdown]
# Выберем все статьи Известий, количество слов в которых больше среднего количества слов по корпусу.
# Для этого выполним многотабличный запрос: обратимся к таблицам corpus и corpus_words с применением RIGHT JOIN (потому что мы удалили некоторые статьи Ленты из таблицы corpus и не для каждой строки из corpus_words найдется соответствующая строка из corpus.
# Чтобы столбцы таблиц не дублировались (в некоторых содержатся одинаковые значения), в явном виде пропишем, какие столбцы из каких таблиц мы хотим видеть:

# %%
# %%time
con = psycopg2.connect(
  database="russian-news", 
  user="postgres", 
  password="passcode4854", 
  host="127.0.0.1", 
  port="5432"
)
cur = con.cursor()
cur.execute("SELECT corpus_words.id, newspaper, date, corpus_words.title, article, corpus_words.n_words FROM corpus RIGHT JOIN corpus_words ON corpus.title = corpus_words.title WHERE n_words > (SELECT AVG(n_words) FROM corpus_words) ORDER BY id")
data=cur.fetchall()
print(data)
con.close()
# Out:
David Granot) ограничился сокращением своей зарплаты на те же 5 процентов. Тем не менее, по оценке экспертов банка, жалованье Гранота в 2002 году составит около 3 млн шекелей.Самый радикальный шаг сделал председатель совета директоров FIBI Шломо Пиотрковский (Shlomo Piotrkowsky). Он заявил, что вообще отказывается от зарплаты и в течение всего 2002 года будет работать на своем посту бесплатно. По оценкам, зарплата председателя FIBI должна была составить не менее 1,7 ...
# Wall time: 140 ms

# %% [markdown]
# Теперь выберем все статьи РИА-новостей, кол-во слов и предложений в которой меньше среднего по корпусу.
# Для этого привяжем с помощью RIGHT JOIN третью таблицу - corpus_sents:

# %%
# %%time
con = psycopg2.connect(
  database="russian-news", 
  user="postgres", 
  password="passcode4854", 
  host="127.0.0.1", 
  port="5432"
)
cur = con.cursor()
cur.execute("SELECT corpus_words.id, newspaper, date, corpus_words.title, article, corpus_words.n_words, corpus_sents.n_sents FROM corpus RIGHT JOIN corpus_words ON corpus.title = corpus_words.title RIGHT JOIN corpus_sents ON corpus.title = corpus_sents.title WHERE n_words < (SELECT AVG(n_words) FROM corpus_words) AND n_sents < (SELECT AVG(n_sents) FROM corpus_sents) AND corpus.newspaper = 'ria' ORDER BY id")
data=cur.fetchall()
print(data)
con.close()
# Out:
# [(601, 'ria', '2001-10-16T17:55:00+03:00', 'На выборах губернатора Орловской области партия "Единство" поддерживает кандидатуру Егора Строева', 'На выборах губернатора Орловской области, намеченных на 28 октября, партия "Единство" поддерживает кандидатуру нынешнего главы областной администрации, спикера Совета Федерации Егора Строева. Об этом заявил журналистам во вторник исполняющий обязанности председателя политсовета "Единство" Франц Клинцевич. На заседании президиума политсовета, состоявшемся во вторник, рассматривались итоги выборов в регионах, а также вопросы подготовки к третьему съезду "Единства", который должен состояться 27 октября, и объединительному съезду "Единство" и "Отечество". Сразу же после окончания заседания президиума политсовета "Единство" началось заседание генерального совета Союза "Единство" и "Отечество". В заседании, которое проходит в закрытом режиме, принимают участие лидеры двух организаций Сергей Шойгу и Юрий...\n МОСКВА, 16 октября. /Корр. РИА "Новости" Николай Макаров/. На выборах \n губернатора Орловской области, намеченных на 28 октября, партия "Единство" \n поддерживает кандидатуру нынешнего главы областной администрации, спикера Совета \n Федерации Егора Строева. Об этом заявил журналистам во вторник исполняющий \n обязанности председателя политсовета "Единство" Франц Клинцевич.\tНа заседании президиума политсовета, состоявшемся во вторник, рассматривались итоги выборов в регионах, а также вопросы подготовки к третьему съезду "Единства", который должен состояться 27 октября, и объединительному съезду "Единство" и "Отечество".\tСразу же после окончания заседания президиума \n политсовета "Единство" началось заседание генерального совета Союза "Единство" и \n "Отечество". В заседании, которое проходит в закрытом режиме, принимают участие \n лидеры двух организаций Сергей Шойгу и Юрий Лужков.', 205, 16), (602, 'ria', '2001-10-16T20:00:00+03:00', 'Правительство России приняло решение о ликвидации Федерального экологического фонда РФ', 'Правительство России приняло предложение Минприроды РФ о ликвидации Федерального экологического фонда РФ, образованного в 1992. Такое решение было согласовано с Минфином, Минимуществом и Минюстом РФ. Об этом РИА "Новости" во вторник сообщили в Департаменте правительственной информации. Минприроды поручено образовать ликвидационную комиссию, составить смету расходов на проведение ликвидационных мероприятий за счет остатков средств на счетах фонда и провести соответствующие мероприятия. Кроме того, Минимуществу совместно с Минприроды поручено представить в правительство предложения об использовании имущества, оставшегося после ликвидации Федерального экологического...\n МОСКВА, 16 октября. /Корр. РИА "Новости"/. Правительство \n России приняло предложение Минприроды РФ о ликвидации Федерального \n экологического фонда РФ, образованного в 1992. Такое решение было согласовано с \n Минфином, Минимуществом и Минюстом РФ. Об этом РИА "Новости" во вторник сообщили \n в Департаменте правительственной информации.\tМинприроды поручено образовать ликвидационную комиссию, составить смету расходов на проведение ликвидационных мероприятий за счет остатков средств на счетах фонда и провести соответствующие мероприятия.\tКроме того, Минимуществу совместно с Минприроды поручено \n представить в правительство предложения об использовании имущества, оставшегося \n после ликвидации Федерального экологического фонда.', 163, 16), (603, 'ria', '2001-10-16T20:02:00+03:00', 'Украина и Белоруссия намерены развивать торгово-экономическое сотрудничество', 'Украина и Белоруссия заинтересованы в углублении торгово-экономического сотрудничества. Об этом, как передает корреспондент РИА "Новости", заявили на состоявшейся во вторник встрече премьер-министр Украины Анатолий Кинах и его белорусский коллега Геннадий Новицкий. Новицкий находится в Киеве с первым официальным визитом в качестве главы белорусского правительства. Как считает премьер-министр Украины, "есть все о ...
# Wall time: 93.9 ms

# %% [markdown]
# Запишем полученные данные в новую таблицу - new_corpus:

# %%
con = psycopg2.connect(
  database="russian-news", 
  user="postgres", 
  password="passcode4854", 
  host="127.0.0.1", 
  port="5432"
)
cur = con.cursor()  
cur.execute('''CREATE TABLE new_corpus  
     (id INT NOT NULL,
     newspaper TEXT,
     date TEXT,
     title TEXT NOT NULL,
     article TEXT,
     n_words INT NOT NULL,
     n_sents INT NOT NULL);''')

print("Table created successfully")
con.commit()  
con.close()
# Out:
# Table created successfully

# %%
# %%time
con = psycopg2.connect(
  database="russian-news", 
  user="postgres", 
  password="passcode4854", 
  host="127.0.0.1", 
  port="5432"
)
user_records = ", ".join(["%s"] * len(data))

insert_query = (
    f"INSERT INTO new_corpus (id, newspaper, date, title, article, n_words, n_sents) VALUES {user_records}"
)

cursor = con.cursor()
cursor.execute(insert_query, data)
con.commit()  
con.close()
# Out:
# Wall time: 114 ms

# %% [markdown]
# Столбец id неинформативен, можно его удалить:

# %%
# %%time
con = psycopg2.connect(
  database="russian-news", 
  user="postgres", 
  password="passcode4854", 
  host="127.0.0.1", 
  port="5432"
)
cur = con.cursor()
cur.execute("ALTER TABLE new_corpus DROP COLUMN id")
con.commit()  
con.close()
# Out:
# Wall time: 88.4 ms

# %%
Таблицу corpus тоже удалим:

# %%
# %%time
con = psycopg2.connect(
  database="russian-news", 
  user="postgres", 
  password="passcode4854", 
  host="127.0.0.1", 
  port="5432"
)
cur = con.cursor()
cur.execute("DROP TABLE corpus")
con.commit()  
con.close()
# Out:
# Wall time: 103 ms

# %%
# Out:
# list
